# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_merged_data = pd.read_csv("Combined_Rental_Median_Price_Inventory.csv")
df_merged_data.head()
# Out:
#          Borough  2010 Total Rentals 2010 Median Rent  2011 Total Rentals  \
# 0          Bronx                3087         $1425.00                3674
# 1       Brooklyn               59006         $2033.50               65757
# 2      Manhattan              441207         $2847.50              395231
# 3         Queens               19596         $1538.25               18369
# 4  Staten Island                  55             $nan                  57
#
#   2011 Median Rent  2012 Total Rentals 2012 Median Rent  2013 Total Rentals  \
# 0         $1210.75                5419         $1425.00                5462
# 1         $1743.75               83105         $1900.00              136910
# 2         $3157.00              456434         $3275.00              576566
# 3         $1550.00               30753         $1825.00               40171
# 4             $nan                 139         $1400.00                 331
#
# ...

# %%
df_median_price = pd.read_csv("Yearly_Median_Rent_DF.csv")
df_median_price.head()
# Out:
#          Borough      2010      2011      2012      2013      2014      2015  \
# 0      Manhattan  $2847.50  $3157.00  $3275.00  $3282.50  $3270.00  $3394.00
# 1         Queens  $1538.25  $1550.00  $1825.00  $1743.75  $1799.00  $1850.00
# 2       Brooklyn  $2033.50  $1743.75  $1900.00  $2106.25  $2225.00  $2300.00
# 3          Bronx  $1425.00  $1210.75  $1425.00  $1275.00  $1331.50  $1400.00
# 4  Staten Island      $nan      $nan  $1400.00  $1487.50  $1675.00  $1662.50
#
#        2016      2017      2018      2019      2020      2021      2022  \
# 0  $3412.50  $3318.00  $3334.50  $3500.00  $3172.50  $3267.50  $4213.00
# 1  $1937.50  $1993.00  $2000.00  $2010.75  $2025.00  $2004.25  $2300.00
# 2  $2300.00  $2335.00  $2400.00  $2450.00  $2475.00  $2256.00  $2847.50
# 3  $1552.00  $1695.00  $1800.00  $1829.00  $1850.00  $1851.00  $1985.00
# 4  $1990.00  $1921.50  $1865.00  $2022.50  $1925.00  $1975.00  $2050.00
#
#        2023
# 0  $4471.50
# 1  $2500.00
# 2  $3125.00
# 3  $2191.00
# ...

# %%
data = pd.read_csv('your_data.csv')

# Extract the borough names
boroughs = data['Borough']

# Extract and clean the median rent values by removing '$' and converting to float
years = [str(year) for year in range(2010, 2024)]
for year in years:
    data[year] = data[year].str.replace('$', '').astype(float)

# Sort the data by median rent in descending order for each year
sorted_data = data[years].apply(pd.to_numeric).sort_values(by=years, axis=1, ascending=False)

# Create a bar chart for median rental prices by borough
plt.figure(figsize=(12, 6))
bar_width = 0.15
index = range(len(boroughs))

for i, year in enumerate(years):
    median_rent = sorted_data[year]
    plt.bar([x + i * bar_width for x in index], median_rent, width=bar_width, label=year)

plt.xlabel('Borough')
plt.ylabel('Median Rent')
plt.title('Median Rental Prices by Borough (2010-2023, Descending Order)')
plt.xticks([x + bar_width * (len(years) - 1) / 2 for x in index], boroughs)
plt.legend(title='Year')
plt.grid(axis='y')
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 data = pd.read_csv('your_data.csv')
#       3 # Extract the borough names
#       4 boroughs = data['Borough']
#
# File ~\anaconda3\envs\Python\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
